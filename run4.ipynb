# %%
import os       
os.chdir('/workspace/my_cyclegan')

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
--gpu_ids 3\
--upsampling_type transpose\
--use_mean_matching\
--name mean_maching_transpose\
--gan_mode lsgan\
--n_blocks 6\
--ngf_depth 20\
--ngf_img 32\
--num_iter_gen 3\
--num_iter_dis 1\
--l_depth_A_begin 10.0\
--l_depth_A_end 0.0\
--l_depth_B_begin 1.0\
--l_depth_B_end 0.0\
--l_depth_max_iter 10000\
--l_cycle_A_begin 30.0\
--l_cycle_A_end 30.0\
--l_identity 0.0\
--max_dataset_size 20000\
--data_shuffle\
--batch_size 8\
--lr_D 0.0001\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 1\
--n_epochs 10\
--n_epochs_decay 5
# Out:
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 5]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#              data_shuffle: True                          	[default: False]
#                  dataroot: /all_data/hdd/un_depth/semi/sample
#              dataset_mode: semi_cycle
#             deterministic: False
#          disc_for_normals: False
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 3                             	[default: 0,1]
#                  img_freq: 40                            	[default: 1]
#                 init_type: xavier
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 30.0                          	[default: 10.0]
#             l_cycle_A_end: 30.0                          	[default: 10.0]
#           l_cycle_B_begin: 10.0
#             l_cycle_B_end: 10.0
#           l_depth_A_begin: 10.0                          	[default: 5.0]
#             l_depth_A_end: 0.0
#           l_depth_B_begin: 1.0                           	[default: 5.0]
#             l_depth_B_end: 0.0
#          l_depth_max_iter: 10000                         	[default: 5000]
#                l_identity: 0.0
# l_reconstruction_semantic: 0.0
#                load_epoch: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 480
#               load_size_w: 640
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0001                        	[default: 0.0002]
#                      lr_G: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 20000                         	[default: inf]
#              max_distance: 8000.0
#                     model: semi_cycle_gan
#                  n_blocks: 6                             	[default: 9]
#            n_downsampling: 2
#                  n_epochs: 10                            	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: mean_maching_transpose        	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 20                            	[default: 32]
#                   ngf_img: 32
#                      norm: instance
#              num_iter_dis: 1
#              num_iter_gen: 3                             	[default: 1]
#               num_workers: 4
#             old_generator: False
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 1                             	[default: 10]
#           upsampling_type: transpose                     	[default: upconv]
#                  use_blur: False
#         use_mean_matching: True                          	[default: False]
#          use_second_cycle: False
#              use_semantic: False
#                   verbose: False
# ----------------- End -------------------
# wandb: Tracking run with wandb version 0.9.7
# wandb: Wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Run data is saved locally in wandb/run-20201025_210054-2mzsectd
# wandb: Syncing run mean_maching_transpose
# wandb: ⭐️ View project at https://app.wandb.ai/maxs/depth_super_res
# wandb: 🚀 View run at https://app.wandb.ai/maxs/depth_super_res/runs/2mzsectd
# wandb: Run `wandb off` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 20000
# initialize network with xavier
# initialize network with xavier
# initialize network with xavier
# initialize network with xavier
# model [SemiCycleGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 5.344 M
# [Network netG_B] Total number of parameters : 3.283 M
# [Network netD_A_depth] Total number of parameters : 2.763 M
# [Network netD_B_depth] Total number of parameters : 2.763 M
# -----------------------------------------------
# D_A loss : 0.537, D_B loss : 0.395
# 320 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.828, D_B loss : 0.319
# 640 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.173, D_B loss : 0.284
# 960 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.138, D_B loss : 0.265
# 1280 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.179, D_B loss : 0.263
# 1600 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.133, D_B loss : 0.221
# 1920 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.214, D_B loss : 0.246
# 2240 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.122, D_B loss : 0.274
# 2560 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.079, D_B loss : 0.266
# 2880 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.122, D_B loss : 0.237
# 3200 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.091, D_B loss : 0.214
# 3520 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.162, D_B loss : 0.196
# 3840 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.080, D_B loss : 0.264
# 4160 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.097, D_B loss : 0.183
# 4480 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.069, D_B loss : 0.235
# 4800 img procesed out of 20000, taken 1.70 sec per 1 batch
# D_A loss : 0.095, D_B loss : 0.217
# 5120 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.051, D_B loss : 0.189
# 5440 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.073, D_B loss : 0.335
# 5760 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.087, D_B loss : 0.200
# 6080 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.104, D_B loss : 0.117
# 6400 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.067, D_B loss : 0.177
# 6720 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.048, D_B loss : 0.125
# 7040 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.085, D_B loss : 0.251
# 7360 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.171, D_B loss : 0.177
# 7680 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.073, D_B loss : 0.196
# 8000 img procesed out of 20000, taken 1.96 sec per 1 batch
# D_A loss : 0.102, D_B loss : 0.173
# 8320 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.044, D_B loss : 0.125
# 8640 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.077, D_B loss : 0.160
# 8960 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.055, D_B loss : 0.203
# 9280 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.082, D_B loss : 0.181
# 9600 img procesed out of 20000, taken 1.70 sec per 1 batch
# D_A loss : 0.101, D_B loss : 0.333
# 9920 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.087, D_B loss : 0.237
# 10240 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.028, D_B loss : 0.162
# 10560 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.038, D_B loss : 0.175
# 10880 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.084, D_B loss : 0.190
# 11200 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.063, D_B loss : 0.229
# 11520 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.080, D_B loss : 0.165
# 11840 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.102, D_B loss : 0.172
# 12160 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.044, D_B loss : 0.196
# 12480 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.040, D_B loss : 0.213
# 12800 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.029, D_B loss : 0.138
# 13120 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.067, D_B loss : 0.217
# 13440 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.073, D_B loss : 0.207
# 13760 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.050, D_B loss : 0.146
# 14080 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.080, D_B loss : 0.096
# 14400 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.046, D_B loss : 0.110
# 14720 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.019, D_B loss : 0.139
# 15040 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.021, D_B loss : 0.157
# 15360 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.054, D_B loss : 0.126
# 15680 img procesed out of 20000, taken 1.70 sec per 1 batch
# D_A loss : 0.021, D_B loss : 0.124
# 16000 img procesed out of 20000, taken 2.01 sec per 1 batch
# D_A loss : 0.073, D_B loss : 0.141
# 16320 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.045, D_B loss : 0.189
# 16640 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.024, D_B loss : 0.204
# 16960 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.029, D_B loss : 0.127
# 17280 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.025, D_B loss : 0.288
# 17600 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.031, D_B loss : 0.142
# 17920 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.038, D_B loss : 0.113
# 18240 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.037, D_B loss : 0.127
# 18560 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.040, D_B loss : 0.133
# 18880 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.045, D_B loss : 0.120
# 19200 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.042, D_B loss : 0.194
# 19520 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.058, D_B loss : 0.154
# 19840 img procesed out of 20000, taken 1.67 sec per 1 batch
# saving the model at the end of epoch 1, iters 2500
# End of epoch 1 / 15 	 Time Taken: 4494.11 sec
# learning rate = 0.0002000
# D_A loss : 0.029, D_B loss : 0.127
# 160 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.261, D_B loss : 0.093
# 480 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.085, D_B loss : 0.133
# 800 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.082, D_B loss : 0.199
# 1120 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.054, D_B loss : 0.198
# 1440 img procesed out of 20000, taken 1.66 sec per 1 batch
# D_A loss : 0.025, D_B loss : 0.260
# 1760 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.028, D_B loss : 0.167
# 2080 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.096, D_B loss : 0.156
# 2400 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.032, D_B loss : 0.117
# 2720 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.037, D_B loss : 0.150
# 3040 img procesed out of 20000, taken 1.67 sec per 1 batch
# D_A loss : 0.016, D_B loss : 0.108
# 3360 img procesed out of 20000, taken 1.68 sec per 1 batch
# D_A loss : 0.050, D_B loss : 0.128
# 3680 img procesed out of 20000, taken 1.69 sec per 1 batch
# D_A loss : 0.072, D_B loss : 0.139
# 4000 img procesed out of 20000, taken 1.93 sec per 1 batch
