# %%
import os
os.chdir('/workspace/my_cyclegan')

# %%
# !python train.py --name test\
--debug\
--datasets Scannet_Interiornet\
--gpu_ids 2\
--batch_size 4\
--disc_for_normals\
--disc_for_depth\
--use_spnorm\
--use_cycle_B\
--l_depth_A_begin 1.\
--l_depth_A_end 1.\
--l_depth_B_begin 1.\
--l_depth_B_end 1.\
--l_cycle_B_begin 5.\
--l_cycle_B_end 5.\
--l_normal 5.\
--l_hole 0.\
--l_max_iter 30000\
--l_num_iter 20000\
--lr_D 0.0001\
--lr_G 0.0003\
--img_freq 40\
--loss_freq 20\
--save_epoch_freq 10\
--n_epochs 20\
--n_epochs_decay 5
# Out:
# ----------------- Options ---------------
#                batch_size: 4                             	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 256
#             crop_size_h_A: 256
#             crop_size_h_B: 512
#               crop_size_w: 256
#             crop_size_w_A: 256
#             crop_size_w_B: 512
#                  dataroot: /all_data/Scannet_ssim
#              dataset_mode: semi_cycle
#                  datasets: Scannet_Interiornet           	[default: Scannet_Scannet]
#                     debug: True                          	[default: False]
#             deterministic: False
#            disc_for_depth: True                          	[default: False]
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 2                             	[default: 1,2]
#               hole_border: -0.97
#             img2depth_dir: ./checkpoints/img2d_pretrain/
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal
#                     inp_B: img_depth
#            input_nc_depth: 1
#              input_nc_img: 3
#             int_mtrx_scan: /all_data/Scannet/
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 0.0
#             l_cycle_A_end: 0.0
#           l_cycle_B_begin: 5.0                           	[default: 0.0]
#             l_cycle_B_end: 5.0                           	[default: 0.0]
#           l_depth_A_begin: 1.0                           	[default: 0.0]
#             l_depth_A_end: 1.0                           	[default: 0.0]
#           l_depth_B_begin: 1.0                           	[default: 0.0]
#             l_depth_B_end: 1.0                           	[default: 0.0]
#                    l_hole: 0.0
#                l_max_iter: 30000                         	[default: 5000]
#                  l_normal: 5.0                           	[default: 1.0]
#                l_num_iter: 20000                         	[default: 5000]
#                load_epoch: last
#      load_epoch_img2depth: last
#        load_epoch_weights: 10
#                 load_iter: 0                             	[default: 0]
#                 loss_freq: 20                            	[default: 1]
#                      lr_D: 0.0001                        	[default: 0.0002]
#                      lr_G: 0.0003                        	[default: 0.0002]
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#              max_distance: 5100.0
#                     model: semi_cycle_gan
#                  n_blocks: 9
#            n_downsampling: 2
#                  n_epochs: 20                            	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: test
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32
#                   ngf_img: 32
#           ngf_img_feature: 32
#           no_data_shuffle: False
#                      norm: group
#                    norm_d: none
#              num_iter_dis: 1
#              num_iter_gen: 1
#               num_workers: 4
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 10
#           upsampling_type: transpose
#               use_cycle_A: False
#               use_cycle_B: True                          	[default: False]
#            use_cycle_disc: False
#    use_pretrain_img2depth: False
#    use_pretrain_weights_A: False
#    use_pretrain_weights_B: False
#              use_semantic: False
#      use_semi_cycle_first: False
#     use_semi_cycle_second: False
#                use_spnorm: True                          	[default: False]
#                   verbose: False
#                 w_decay_G: 0.0001
#               weights_dir: ./checkpoints/pretrain_weights_imgdepht/
# ----------------- End -------------------
# Dataset SemiCycleDataset was created
# The number of training images = 13744
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.6.0
# initialize network with normal
# initialize network with normal
# initialize network with normal
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.6.0
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [SemiCycleGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.713 M
# [Network netG_B] Total number of parameters : 11.713 M
# [Network netD_A_depth] Total number of parameters : 2.762 M
# [Network netD_B_depth] Total number of parameters : 2.762 M
# [Network netD_A_normal] Total number of parameters : 2.764 M
# [Network netD_B_normal] Total number of parameters : 2.764 M
# -----------------------------------------------
# 160 img procesed out of 13744, taken 0.63 sec per 1 batch
# 320 img procesed out of 13744, taken 0.63 sec per 1 batch
# 480 img procesed out of 13744, taken 0.63 sec per 1 batch
# 640 img procesed out of 13744, taken 0.64 sec per 1 batch
# 800 img procesed out of 13744, taken 0.65 sec per 1 batch
# 960 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1120 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1280 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1440 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1600 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1760 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1920 img procesed out of 13744, taken 0.65 sec per 1 batch
# 2080 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2240 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2400 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2560 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2720 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2880 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3040 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3200 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3360 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3520 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3680 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3840 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4000 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4160 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4320 img procesed out of 13744, taken 0.65 sec per 1 batch
# 4480 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4640 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4800 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4960 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5120 img procesed out of 13744, taken 0.65 sec per 1 batch
# 5280 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5440 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5600 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5760 img procesed out of 13744, taken 0.65 sec per 1 batch
# 5920 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6080 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6240 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6400 img procesed out of 13744, taken 0.65 sec per 1 batch
# 6560 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6720 img procesed out of 13744, taken 0.65 sec per 1 batch
# 6880 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7040 img procesed out of 13744, taken 0.65 sec per 1 batch
# 7200 img procesed out of 13744, taken 0.65 sec per 1 batch
# 7360 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7520 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7680 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7840 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8000 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8160 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8320 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8480 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8640 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8800 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8960 img procesed out of 13744, taken 0.65 sec per 1 batch
# 9120 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9280 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9440 img procesed out of 13744, taken 0.65 sec per 1 batch
# 9600 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9760 img procesed out of 13744, taken 0.65 sec per 1 batch
# 9920 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10080 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10240 img procesed out of 13744, taken 0.65 sec per 1 batch
# 10400 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10560 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10720 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10880 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11040 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11200 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11360 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11520 img procesed out of 13744, taken 0.65 sec per 1 batch
# 11680 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11840 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12000 img procesed out of 13744, taken 0.65 sec per 1 batch
# 12160 img procesed out of 13744, taken 0.65 sec per 1 batch
# 12320 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12480 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12640 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12800 img procesed out of 13744, taken 0.65 sec per 1 batch
# 12960 img procesed out of 13744, taken 0.65 sec per 1 batch
# 13120 img procesed out of 13744, taken 0.65 sec per 1 batch
# 13280 img procesed out of 13744, taken 0.66 sec per 1 batch
# 13440 img procesed out of 13744, taken 0.65 sec per 1 batch
# 13600 img procesed out of 13744, taken 0.64 sec per 1 batch
# End of epoch 1 / 25 	 Time Taken: 2271.69 sec
# learning rate = 0.0003000
# 16 img procesed out of 13744, taken 0.65 sec per 1 batch
# 176 img procesed out of 13744, taken 0.65 sec per 1 batch
# 336 img procesed out of 13744, taken 0.64 sec per 1 batch
# 496 img procesed out of 13744, taken 0.62 sec per 1 batch
# 656 img procesed out of 13744, taken 0.64 sec per 1 batch
# 816 img procesed out of 13744, taken 0.63 sec per 1 batch
# 976 img procesed out of 13744, taken 0.66 sec per 1 batch
# 1136 img procesed out of 13744, taken 0.65 sec per 1 batch
# 1296 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1456 img procesed out of 13744, taken 0.65 sec per 1 batch
# 1616 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1776 img procesed out of 13744, taken 0.65 sec per 1 batch
# 1936 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2096 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2256 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2416 img procesed out of 13744, taken 0.65 sec per 1 batch
# 2576 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2736 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2896 img procesed out of 13744, taken 0.63 sec per 1 batch
# 3056 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3216 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3376 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3536 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3696 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3856 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4016 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4176 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4336 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4496 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4656 img procesed out of 13744, taken 0.65 sec per 1 batch
# 4816 img procesed out of 13744, taken 0.66 sec per 1 batch
# 4976 img procesed out of 13744, taken 0.65 sec per 1 batch
# 5136 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5296 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5456 img procesed out of 13744, taken 0.66 sec per 1 batch
# 5616 img procesed out of 13744, taken 0.66 sec per 1 batch
# 5776 img procesed out of 13744, taken 0.66 sec per 1 batch
# 5936 img procesed out of 13744, taken 0.65 sec per 1 batch
# 6096 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6256 img procesed out of 13744, taken 0.66 sec per 1 batch
# 6416 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6576 img procesed out of 13744, taken 0.65 sec per 1 batch
# 6736 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6896 img procesed out of 13744, taken 0.63 sec per 1 batch
# All values are same
# Try new img
# 7056 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7216 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7376 img procesed out of 13744, taken 0.65 sec per 1 batch
# 7536 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7696 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7856 img procesed out of 13744, taken 0.65 sec per 1 batch
# 8016 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8176 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8336 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8496 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8656 img procesed out of 13744, taken 0.65 sec per 1 batch
# 8816 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8976 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9136 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9296 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9456 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9616 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9776 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9936 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10096 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10256 img procesed out of 13744, taken 0.66 sec per 1 batch
# 10416 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10576 img procesed out of 13744, taken 0.65 sec per 1 batch
# 10736 img procesed out of 13744, taken 0.65 sec per 1 batch
# 10896 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11056 img procesed out of 13744, taken 0.65 sec per 1 batch
# 11216 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11376 img procesed out of 13744, taken 0.66 sec per 1 batch
# 11536 img procesed out of 13744, taken 0.67 sec per 1 batch
# 11696 img procesed out of 13744, taken 0.65 sec per 1 batch
# 11856 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12016 img procesed out of 13744, taken 0.65 sec per 1 batch
# 12176 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12336 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12496 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12656 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12816 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12976 img procesed out of 13744, taken 0.64 sec per 1 batch
# 13136 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13296 img procesed out of 13744, taken 0.65 sec per 1 batch
# 13456 img procesed out of 13744, taken 0.64 sec per 1 batch
# 13616 img procesed out of 13744, taken 0.63 sec per 1 batch
# End of epoch 2 / 25 	 Time Taken: 2275.35 sec
# learning rate = 0.0003000
# 32 img procesed out of 13744, taken 0.64 sec per 1 batch
# 192 img procesed out of 13744, taken 0.65 sec per 1 batch
# 352 img procesed out of 13744, taken 0.64 sec per 1 batch
# 512 img procesed out of 13744, taken 0.63 sec per 1 batch
# 672 img procesed out of 13744, taken 0.64 sec per 1 batch
# 832 img procesed out of 13744, taken 0.64 sec per 1 batch
# 992 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1152 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1312 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1472 img procesed out of 13744, taken 0.65 sec per 1 batch
# 1632 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1792 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1952 img procesed out of 13744, taken 0.65 sec per 1 batch
# 2112 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2272 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2432 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2592 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2752 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2912 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3072 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3232 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3392 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3552 img procesed out of 13744, taken 0.63 sec per 1 batch
# 3712 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3872 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4032 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4192 img procesed out of 13744, taken 0.66 sec per 1 batch
# 4352 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4512 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4672 img procesed out of 13744, taken 0.65 sec per 1 batch
# 4832 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4992 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5152 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5312 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5472 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5632 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5792 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5952 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6112 img procesed out of 13744, taken 0.65 sec per 1 batch
# 6272 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6432 img procesed out of 13744, taken 0.64 sec per 1 batch
# All values are same
# Try new img
# 6592 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6752 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6912 img procesed out of 13744, taken 0.65 sec per 1 batch
# 7072 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7232 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7392 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7552 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7712 img procesed out of 13744, taken 0.66 sec per 1 batch
# 7872 img procesed out of 13744, taken 0.65 sec per 1 batch
# 8032 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8192 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8352 img procesed out of 13744, taken 0.65 sec per 1 batch
# 8512 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8672 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8832 img procesed out of 13744, taken 0.65 sec per 1 batch
# 8992 img procesed out of 13744, taken 0.65 sec per 1 batch
# 9152 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9312 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9472 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9632 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9792 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9952 img procesed out of 13744, taken 0.66 sec per 1 batch
# 10112 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10272 img procesed out of 13744, taken 0.79 sec per 1 batch
# 10432 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10592 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10752 img procesed out of 13744, taken 0.65 sec per 1 batch
# 10912 img procesed out of 13744, taken 0.68 sec per 1 batch
# 11072 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11232 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11392 img procesed out of 13744, taken 0.79 sec per 1 batch
# 11552 img procesed out of 13744, taken 0.76 sec per 1 batch
# 11712 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11872 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12032 img procesed out of 13744, taken 0.74 sec per 1 batch
# 12192 img procesed out of 13744, taken 0.79 sec per 1 batch
# 12352 img procesed out of 13744, taken 0.74 sec per 1 batch
# 12512 img procesed out of 13744, taken 0.75 sec per 1 batch
# 12672 img procesed out of 13744, taken 0.79 sec per 1 batch
# 12832 img procesed out of 13744, taken 0.73 sec per 1 batch
# 12992 img procesed out of 13744, taken 0.77 sec per 1 batch
# 13152 img procesed out of 13744, taken 0.77 sec per 1 batch
# 13312 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13472 img procesed out of 13744, taken 0.72 sec per 1 batch
# 13632 img procesed out of 13744, taken 0.79 sec per 1 batch
# End of epoch 3 / 25 	 Time Taken: 2348.63 sec
# learning rate = 0.0003000
# 48 img procesed out of 13744, taken 0.72 sec per 1 batch
# 208 img procesed out of 13744, taken 0.73 sec per 1 batch
# 368 img procesed out of 13744, taken 0.78 sec per 1 batch
# 528 img procesed out of 13744, taken 0.75 sec per 1 batch
# 688 img procesed out of 13744, taken 0.73 sec per 1 batch
# 848 img procesed out of 13744, taken 0.74 sec per 1 batch
# 1008 img procesed out of 13744, taken 0.78 sec per 1 batch
# 1168 img procesed out of 13744, taken 0.79 sec per 1 batch
# 1328 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1488 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1648 img procesed out of 13744, taken 0.76 sec per 1 batch
# 1808 img procesed out of 13744, taken 0.79 sec per 1 batch
# 1968 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2128 img procesed out of 13744, taken 0.80 sec per 1 batch
# 2288 img procesed out of 13744, taken 0.76 sec per 1 batch
# 2448 img procesed out of 13744, taken 0.79 sec per 1 batch
# 2608 img procesed out of 13744, taken 0.79 sec per 1 batch
# 2768 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2928 img procesed out of 13744, taken 0.78 sec per 1 batch
# 3088 img procesed out of 13744, taken 0.75 sec per 1 batch
# 3248 img procesed out of 13744, taken 0.72 sec per 1 batch
# 3408 img procesed out of 13744, taken 0.73 sec per 1 batch
# 3568 img procesed out of 13744, taken 0.78 sec per 1 batch
# 3728 img procesed out of 13744, taken 0.79 sec per 1 batch
# 3888 img procesed out of 13744, taken 0.80 sec per 1 batch
# 4048 img procesed out of 13744, taken 0.73 sec per 1 batch
# 4208 img procesed out of 13744, taken 0.77 sec per 1 batch
# 4368 img procesed out of 13744, taken 0.78 sec per 1 batch
# 4528 img procesed out of 13744, taken 0.75 sec per 1 batch
# 4688 img procesed out of 13744, taken 0.78 sec per 1 batch
# 4848 img procesed out of 13744, taken 0.79 sec per 1 batch
# 5008 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5168 img procesed out of 13744, taken 0.73 sec per 1 batch
# 5328 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5488 img procesed out of 13744, taken 0.80 sec per 1 batch
# 5648 img procesed out of 13744, taken 0.79 sec per 1 batch
# 5808 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5968 img procesed out of 13744, taken 0.72 sec per 1 batch
# 6128 img procesed out of 13744, taken 0.79 sec per 1 batch
# 6288 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6448 img procesed out of 13744, taken 0.73 sec per 1 batch
# 6608 img procesed out of 13744, taken 0.78 sec per 1 batch
# 6768 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6928 img procesed out of 13744, taken 0.78 sec per 1 batch
# 7088 img procesed out of 13744, taken 0.80 sec per 1 batch
# 7248 img procesed out of 13744, taken 0.78 sec per 1 batch
# 7408 img procesed out of 13744, taken 0.78 sec per 1 batch
# 7568 img procesed out of 13744, taken 0.78 sec per 1 batch
# 7728 img procesed out of 13744, taken 0.79 sec per 1 batch
# 7888 img procesed out of 13744, taken 0.76 sec per 1 batch
# 8048 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8208 img procesed out of 13744, taken 0.73 sec per 1 batch
# 8368 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8528 img procesed out of 13744, taken 0.77 sec per 1 batch
# 8688 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8848 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9008 img procesed out of 13744, taken 0.79 sec per 1 batch
# 9168 img procesed out of 13744, taken 0.72 sec per 1 batch
# 9328 img procesed out of 13744, taken 0.79 sec per 1 batch
# 9488 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9648 img procesed out of 13744, taken 0.81 sec per 1 batch
# 9808 img procesed out of 13744, taken 0.78 sec per 1 batch
# 9968 img procesed out of 13744, taken 0.79 sec per 1 batch
# 10128 img procesed out of 13744, taken 0.78 sec per 1 batch
# 10288 img procesed out of 13744, taken 0.75 sec per 1 batch
# 10448 img procesed out of 13744, taken 0.73 sec per 1 batch
# 10608 img procesed out of 13744, taken 0.72 sec per 1 batch
# 10768 img procesed out of 13744, taken 0.80 sec per 1 batch
# 10928 img procesed out of 13744, taken 0.78 sec per 1 batch
# 11088 img procesed out of 13744, taken 0.78 sec per 1 batch
# 11248 img procesed out of 13744, taken 0.75 sec per 1 batch
# 11408 img procesed out of 13744, taken 0.79 sec per 1 batch
# 11568 img procesed out of 13744, taken 0.73 sec per 1 batch
# All values are same
# Try new img
# 11728 img procesed out of 13744, taken 0.80 sec per 1 batch
# 11888 img procesed out of 13744, taken 0.77 sec per 1 batch
# 12048 img procesed out of 13744, taken 0.75 sec per 1 batch
# 12208 img procesed out of 13744, taken 0.77 sec per 1 batch
# 12368 img procesed out of 13744, taken 0.74 sec per 1 batch
# 12528 img procesed out of 13744, taken 0.79 sec per 1 batch
# 12688 img procesed out of 13744, taken 0.72 sec per 1 batch
# 12848 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13008 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13168 img procesed out of 13744, taken 0.77 sec per 1 batch
# 13328 img procesed out of 13744, taken 0.77 sec per 1 batch
# 13488 img procesed out of 13744, taken 0.73 sec per 1 batch
# 13648 img procesed out of 13744, taken 0.79 sec per 1 batch
# End of epoch 4 / 25 	 Time Taken: 2725.17 sec
# learning rate = 0.0003000
# 64 img procesed out of 13744, taken 0.74 sec per 1 batch
# 224 img procesed out of 13744, taken 0.79 sec per 1 batch
# 384 img procesed out of 13744, taken 0.78 sec per 1 batch
# 544 img procesed out of 13744, taken 0.80 sec per 1 batch
# 704 img procesed out of 13744, taken 0.80 sec per 1 batch
# 864 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1024 img procesed out of 13744, taken 0.79 sec per 1 batch
# 1184 img procesed out of 13744, taken 0.78 sec per 1 batch
# 1344 img procesed out of 13744, taken 0.72 sec per 1 batch
# 1504 img procesed out of 13744, taken 0.78 sec per 1 batch
# 1664 img procesed out of 13744, taken 0.78 sec per 1 batch
# 1824 img procesed out of 13744, taken 0.79 sec per 1 batch
# 1984 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2144 img procesed out of 13744, taken 0.76 sec per 1 batch
# 2304 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2464 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2624 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2784 img procesed out of 13744, taken 0.82 sec per 1 batch
# 2944 img procesed out of 13744, taken 0.79 sec per 1 batch
# 3104 img procesed out of 13744, taken 0.74 sec per 1 batch
# 3264 img procesed out of 13744, taken 0.79 sec per 1 batch
# 3424 img procesed out of 13744, taken 0.79 sec per 1 batch
# 3584 img procesed out of 13744, taken 0.78 sec per 1 batch
# 3744 img procesed out of 13744, taken 0.79 sec per 1 batch
# 3904 img procesed out of 13744, taken 0.74 sec per 1 batch
# 4064 img procesed out of 13744, taken 0.73 sec per 1 batch
# 4224 img procesed out of 13744, taken 0.78 sec per 1 batch
# 4384 img procesed out of 13744, taken 0.77 sec per 1 batch
# 4544 img procesed out of 13744, taken 0.75 sec per 1 batch
# 4704 img procesed out of 13744, taken 0.79 sec per 1 batch
# 4864 img procesed out of 13744, taken 0.78 sec per 1 batch
# 5024 img procesed out of 13744, taken 0.79 sec per 1 batch
# 5184 img procesed out of 13744, taken 0.78 sec per 1 batch
# 5344 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5504 img procesed out of 13744, taken 0.79 sec per 1 batch
# 5664 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5824 img procesed out of 13744, taken 0.79 sec per 1 batch
# 5984 img procesed out of 13744, taken 0.73 sec per 1 batch
# 6144 img procesed out of 13744, taken 0.75 sec per 1 batch
# 6304 img procesed out of 13744, taken 0.73 sec per 1 batch
# 6464 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6624 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6784 img procesed out of 13744, taken 0.81 sec per 1 batch
# 6944 img procesed out of 13744, taken 0.76 sec per 1 batch
# 7104 img procesed out of 13744, taken 0.73 sec per 1 batch
# 7264 img procesed out of 13744, taken 0.79 sec per 1 batch
# 7424 img procesed out of 13744, taken 0.81 sec per 1 batch
# 7584 img procesed out of 13744, taken 0.72 sec per 1 batch
# 7744 img procesed out of 13744, taken 0.78 sec per 1 batch
# 7904 img procesed out of 13744, taken 0.77 sec per 1 batch
# 8064 img procesed out of 13744, taken 0.77 sec per 1 batch
# 8224 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8384 img procesed out of 13744, taken 0.79 sec per 1 batch
# 8544 img procesed out of 13744, taken 0.81 sec per 1 batch
# 8704 img procesed out of 13744, taken 0.79 sec per 1 batch
# 8864 img procesed out of 13744, taken 0.72 sec per 1 batch
# 9024 img procesed out of 13744, taken 0.78 sec per 1 batch
# 9184 img procesed out of 13744, taken 0.76 sec per 1 batch
# 9344 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9504 img procesed out of 13744, taken 0.79 sec per 1 batch
# 9664 img procesed out of 13744, taken 0.73 sec per 1 batch
# 9824 img procesed out of 13744, taken 0.78 sec per 1 batch
# 9984 img procesed out of 13744, taken 0.72 sec per 1 batch
# 10144 img procesed out of 13744, taken 0.79 sec per 1 batch
# 10304 img procesed out of 13744, taken 0.76 sec per 1 batch
# 10464 img procesed out of 13744, taken 0.77 sec per 1 batch
# 10624 img procesed out of 13744, taken 0.79 sec per 1 batch
# 10784 img procesed out of 13744, taken 0.77 sec per 1 batch
# 10944 img procesed out of 13744, taken 0.78 sec per 1 batch
# 11104 img procesed out of 13744, taken 0.79 sec per 1 batch
# 11264 img procesed out of 13744, taken 0.79 sec per 1 batch
# 11424 img procesed out of 13744, taken 0.78 sec per 1 batch
# 11584 img procesed out of 13744, taken 0.72 sec per 1 batch
# 11744 img procesed out of 13744, taken 0.79 sec per 1 batch
# 11904 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12064 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12224 img procesed out of 13744, taken 0.75 sec per 1 batch
# 12384 img procesed out of 13744, taken 0.79 sec per 1 batch
# 12544 img procesed out of 13744, taken 0.73 sec per 1 batch
# 12704 img procesed out of 13744, taken 0.79 sec per 1 batch
# 12864 img procesed out of 13744, taken 0.78 sec per 1 batch
# 13024 img procesed out of 13744, taken 0.73 sec per 1 batch
# 13184 img procesed out of 13744, taken 0.74 sec per 1 batch
# 13344 img procesed out of 13744, taken 0.73 sec per 1 batch
# 13504 img procesed out of 13744, taken 0.73 sec per 1 batch
# 13664 img procesed out of 13744, taken 0.79 sec per 1 batch
# End of epoch 5 / 25 	 Time Taken: 2724.47 sec
# learning rate = 0.0003000
# 80 img procesed out of 13744, taken 0.79 sec per 1 batch
# 240 img procesed out of 13744, taken 0.73 sec per 1 batch
# 400 img procesed out of 13744, taken 0.80 sec per 1 batch
# 560 img procesed out of 13744, taken 0.76 sec per 1 batch
# 720 img procesed out of 13744, taken 0.70 sec per 1 batch
# 880 img procesed out of 13744, taken 0.78 sec per 1 batch
# 1040 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1200 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1360 img procesed out of 13744, taken 0.79 sec per 1 batch
# 1520 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1680 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1840 img procesed out of 13744, taken 0.73 sec per 1 batch
# 2000 img procesed out of 13744, taken 0.73 sec per 1 batch
# 2160 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2320 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2480 img procesed out of 13744, taken 0.72 sec per 1 batch
# 2640 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2800 img procesed out of 13744, taken 0.72 sec per 1 batch
# 2960 img procesed out of 13744, taken 0.79 sec per 1 batch
# 3120 img procesed out of 13744, taken 0.78 sec per 1 batch
# 3280 img procesed out of 13744, taken 0.78 sec per 1 batch
# 3440 img procesed out of 13744, taken 0.79 sec per 1 batch
# 3600 img procesed out of 13744, taken 0.77 sec per 1 batch
# 3760 img procesed out of 13744, taken 0.77 sec per 1 batch
# 3920 img procesed out of 13744, taken 0.79 sec per 1 batch
# 4080 img procesed out of 13744, taken 0.72 sec per 1 batch
# 4240 img procesed out of 13744, taken 0.74 sec per 1 batch
# 4400 img procesed out of 13744, taken 0.71 sec per 1 batch
# 4560 img procesed out of 13744, taken 0.78 sec per 1 batch
# 4720 img procesed out of 13744, taken 0.79 sec per 1 batch
# 4880 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5040 img procesed out of 13744, taken 0.78 sec per 1 batch
# 5200 img procesed out of 13744, taken 0.78 sec per 1 batch
# 5360 img procesed out of 13744, taken 0.79 sec per 1 batch
# 5520 img procesed out of 13744, taken 0.72 sec per 1 batch
# 5680 img procesed out of 13744, taken 0.81 sec per 1 batch
# 5840 img procesed out of 13744, taken 0.78 sec per 1 batch
# 6000 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6160 img procesed out of 13744, taken 0.78 sec per 1 batch
# 6320 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6480 img procesed out of 13744, taken 0.79 sec per 1 batch
# 6640 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6800 img procesed out of 13744, taken 0.79 sec per 1 batch
# 6960 img procesed out of 13744, taken 0.77 sec per 1 batch
# 7120 img procesed out of 13744, taken 0.77 sec per 1 batch
# 7280 img procesed out of 13744, taken 0.77 sec per 1 batch
# 7440 img procesed out of 13744, taken 0.76 sec per 1 batch
# 7600 img procesed out of 13744, taken 0.77 sec per 1 batch
# 7760 img procesed out of 13744, taken 0.77 sec per 1 batch
# 7920 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8080 img procesed out of 13744, taken 0.74 sec per 1 batch
# 8240 img procesed out of 13744, taken 0.79 sec per 1 batch
# 8400 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8560 img procesed out of 13744, taken 0.73 sec per 1 batch
# 8720 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8880 img procesed out of 13744, taken 0.78 sec per 1 batch
# 9040 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9200 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9360 img procesed out of 13744, taken 0.73 sec per 1 batch
# 9520 img procesed out of 13744, taken 0.76 sec per 1 batch
# 9680 img procesed out of 13744, taken 0.79 sec per 1 batch
# 9840 img procesed out of 13744, taken 0.78 sec per 1 batch
# 10000 img procesed out of 13744, taken 0.77 sec per 1 batch
# 10160 img procesed out of 13744, taken 0.77 sec per 1 batch
# 10320 img procesed out of 13744, taken 0.77 sec per 1 batch
# 10480 img procesed out of 13744, taken 0.73 sec per 1 batch
# 10640 img procesed out of 13744, taken 0.78 sec per 1 batch
# 10800 img procesed out of 13744, taken 0.78 sec per 1 batch
# 10960 img procesed out of 13744, taken 0.78 sec per 1 batch
# 11120 img procesed out of 13744, taken 0.77 sec per 1 batch
# 11280 img procesed out of 13744, taken 0.74 sec per 1 batch
# 11440 img procesed out of 13744, taken 0.76 sec per 1 batch
# 11600 img procesed out of 13744, taken 0.72 sec per 1 batch
# 11760 img procesed out of 13744, taken 0.77 sec per 1 batch
# 11920 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12080 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12240 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12400 img procesed out of 13744, taken 0.78 sec per 1 batch
# All values are same
# Try new img
# 12560 img procesed out of 13744, taken 0.72 sec per 1 batch
# 12720 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12880 img procesed out of 13744, taken 0.78 sec per 1 batch
# 13040 img procesed out of 13744, taken 0.77 sec per 1 batch
# 13200 img procesed out of 13744, taken 0.78 sec per 1 batch
# 13360 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13520 img procesed out of 13744, taken 0.77 sec per 1 batch
# 13680 img procesed out of 13744, taken 0.76 sec per 1 batch
# End of epoch 6 / 25 	 Time Taken: 2699.30 sec
# learning rate = 0.0003000
# 96 img procesed out of 13744, taken 0.77 sec per 1 batch
# 256 img procesed out of 13744, taken 0.75 sec per 1 batch
# 416 img procesed out of 13744, taken 0.79 sec per 1 batch
# 576 img procesed out of 13744, taken 0.72 sec per 1 batch
# 736 img procesed out of 13744, taken 0.78 sec per 1 batch
# 896 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1056 img procesed out of 13744, taken 0.72 sec per 1 batch
# 1216 img procesed out of 13744, taken 0.79 sec per 1 batch
# 1376 img procesed out of 13744, taken 0.78 sec per 1 batch
# 1536 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1696 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1856 img procesed out of 13744, taken 0.72 sec per 1 batch
# 2016 img procesed out of 13744, taken 0.72 sec per 1 batch
# 2176 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2336 img procesed out of 13744, taken 0.79 sec per 1 batch
# 2496 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2656 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2816 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2976 img procesed out of 13744, taken 0.64 sec per 1 batch
# All values are same
# Try new img
# 3136 img procesed out of 13744, taken 0.62 sec per 1 batch
# 3296 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3456 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3616 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3776 img procesed out of 13744, taken 0.63 sec per 1 batch
# 3936 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4096 img procesed out of 13744, taken 0.62 sec per 1 batch
# 4256 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4416 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4576 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4736 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4896 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5056 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5216 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5376 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5536 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5696 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5856 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6016 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6176 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6336 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6496 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6656 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6816 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6976 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7136 img procesed out of 13744, taken 0.62 sec per 1 batch
# 7296 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7456 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7616 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7776 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7936 img procesed out of 13744, taken 0.62 sec per 1 batch
# 8096 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8256 img procesed out of 13744, taken 0.65 sec per 1 batch
# 8416 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8576 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8736 img procesed out of 13744, taken 0.65 sec per 1 batch
# 8896 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9056 img procesed out of 13744, taken 0.62 sec per 1 batch
# 9216 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9376 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9536 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9696 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9856 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10016 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10176 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10336 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10496 img procesed out of 13744, taken 0.62 sec per 1 batch
# 10656 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10816 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10976 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11136 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11296 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11456 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11616 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11776 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11936 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12096 img procesed out of 13744, taken 0.62 sec per 1 batch
# 12256 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12416 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12576 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12736 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12896 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13056 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13216 img procesed out of 13744, taken 0.65 sec per 1 batch
# 13376 img procesed out of 13744, taken 0.65 sec per 1 batch
# 13536 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13696 img procesed out of 13744, taken 0.64 sec per 1 batch
# End of epoch 7 / 25 	 Time Taken: 2326.39 sec
# learning rate = 0.0003000
# 112 img procesed out of 13744, taken 0.63 sec per 1 batch
# 272 img procesed out of 13744, taken 0.63 sec per 1 batch
# 432 img procesed out of 13744, taken 0.64 sec per 1 batch
# 592 img procesed out of 13744, taken 0.63 sec per 1 batch
# 752 img procesed out of 13744, taken 0.64 sec per 1 batch
# 912 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1072 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1232 img procesed out of 13744, taken 0.65 sec per 1 batch
# 1392 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1552 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1712 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1872 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2032 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2192 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2352 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2512 img procesed out of 13744, taken 0.65 sec per 1 batch
# 2672 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2832 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2992 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3152 img procesed out of 13744, taken 0.63 sec per 1 batch
# 3312 img procesed out of 13744, taken 0.63 sec per 1 batch
# 3472 img procesed out of 13744, taken 0.62 sec per 1 batch
# 3632 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3792 img procesed out of 13744, taken 0.63 sec per 1 batch
# 3952 img procesed out of 13744, taken 0.65 sec per 1 batch
# 4112 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4272 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4432 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4592 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4752 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4912 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5072 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5232 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5392 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5552 img procesed out of 13744, taken 0.62 sec per 1 batch
# 5712 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5872 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6032 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6192 img procesed out of 13744, taken 0.62 sec per 1 batch
# 6352 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6512 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6672 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6832 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6992 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7152 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7312 img procesed out of 13744, taken 0.65 sec per 1 batch
# 7472 img procesed out of 13744, taken 0.65 sec per 1 batch
# 7632 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7792 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7952 img procesed out of 13744, taken 0.62 sec per 1 batch
# 8112 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8272 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8432 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8592 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8752 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8912 img procesed out of 13744, taken 0.62 sec per 1 batch
# 9072 img procesed out of 13744, taken 0.65 sec per 1 batch
# 9232 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9392 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9552 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9712 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9872 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10032 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10192 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10352 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10512 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10672 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10832 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10992 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11152 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11312 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11472 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11632 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11792 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11952 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12112 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12272 img procesed out of 13744, taken 0.62 sec per 1 batch
# 12432 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12592 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12752 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12912 img procesed out of 13744, taken 0.64 sec per 1 batch
# 13072 img procesed out of 13744, taken 0.64 sec per 1 batch
# 13232 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13392 img procesed out of 13744, taken 0.64 sec per 1 batch
# 13552 img procesed out of 13744, taken 0.63 sec per 1 batch
# ...
# 13216 img procesed out of 13744, taken 0.64 sec per 1 batch
# 13376 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13536 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13696 img procesed out of 13744, taken 0.64 sec per 1 batch
# End of epoch 17 / 25 	 Time Taken: 2258.94 sec
# learning rate = 0.0003000
# 112 img procesed out of 13744, taken 0.63 sec per 1 batch
# 272 img procesed out of 13744, taken 0.63 sec per 1 batch
# 432 img procesed out of 13744, taken 0.66 sec per 1 batch
# 592 img procesed out of 13744, taken 0.63 sec per 1 batch
# 752 img procesed out of 13744, taken 0.64 sec per 1 batch
# 912 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1072 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1232 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1392 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1552 img procesed out of 13744, taken 0.64 sec per 1 batch
# 1712 img procesed out of 13744, taken 0.63 sec per 1 batch
# 1872 img procesed out of 13744, taken 0.65 sec per 1 batch
# 2032 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2192 img procesed out of 13744, taken 0.65 sec per 1 batch
# 2352 img procesed out of 13744, taken 0.65 sec per 1 batch
# 2512 img procesed out of 13744, taken 0.63 sec per 1 batch
# 2672 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2832 img procesed out of 13744, taken 0.64 sec per 1 batch
# 2992 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3152 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3312 img procesed out of 13744, taken 0.63 sec per 1 batch
# 3472 img procesed out of 13744, taken 0.65 sec per 1 batch
# 3632 img procesed out of 13744, taken 0.64 sec per 1 batch
# 3792 img procesed out of 13744, taken 0.63 sec per 1 batch
# 3952 img procesed out of 13744, taken 0.62 sec per 1 batch
# 4112 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4272 img procesed out of 13744, taken 0.64 sec per 1 batch
# 4432 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4592 img procesed out of 13744, taken 0.65 sec per 1 batch
# 4752 img procesed out of 13744, taken 0.63 sec per 1 batch
# 4912 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5072 img procesed out of 13744, taken 0.63 sec per 1 batch
# 5232 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5392 img procesed out of 13744, taken 0.65 sec per 1 batch
# 5552 img procesed out of 13744, taken 0.64 sec per 1 batch
# 5712 img procesed out of 13744, taken 0.62 sec per 1 batch
# 5872 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6032 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6192 img procesed out of 13744, taken 0.63 sec per 1 batch
# 6352 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6512 img procesed out of 13744, taken 0.65 sec per 1 batch
# 6672 img procesed out of 13744, taken 0.66 sec per 1 batch
# 6832 img procesed out of 13744, taken 0.64 sec per 1 batch
# 6992 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7152 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7312 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7472 img procesed out of 13744, taken 0.64 sec per 1 batch
# 7632 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7792 img procesed out of 13744, taken 0.63 sec per 1 batch
# 7952 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8112 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8272 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8432 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8592 img procesed out of 13744, taken 0.63 sec per 1 batch
# 8752 img procesed out of 13744, taken 0.64 sec per 1 batch
# 8912 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9072 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9232 img procesed out of 13744, taken 0.63 sec per 1 batch
# 9392 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9552 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9712 img procesed out of 13744, taken 0.64 sec per 1 batch
# 9872 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10032 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10192 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10352 img procesed out of 13744, taken 0.64 sec per 1 batch
# 10512 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10672 img procesed out of 13744, taken 0.63 sec per 1 batch
# 10832 img procesed out of 13744, taken 0.62 sec per 1 batch
# 10992 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11152 img procesed out of 13744, taken 0.65 sec per 1 batch
# 11312 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11472 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11632 img procesed out of 13744, taken 0.64 sec per 1 batch
# 11792 img procesed out of 13744, taken 0.63 sec per 1 batch
# 11952 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12112 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12272 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12432 img procesed out of 13744, taken 0.63 sec per 1 batch
# 12592 img procesed out of 13744, taken 0.65 sec per 1 batch
# 12752 img procesed out of 13744, taken 0.64 sec per 1 batch
# 12912 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13072 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13232 img procesed out of 13744, taken 0.63 sec per 1 batch
# 13392 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13552 img procesed out of 13744, taken 0.78 sec per 1 batch
# 13712 img procesed out of 13744, taken 0.78 sec per 1 batch
# End of epoch 18 / 25 	 Time Taken: 2276.61 sec
# learning rate = 0.0003000
# 128 img procesed out of 13744, taken 0.77 sec per 1 batch
# 288 img procesed out of 13744, taken 0.78 sec per 1 batch
# 448 img procesed out of 13744, taken 0.71 sec per 1 batch
# 608 img procesed out of 13744, taken 0.73 sec per 1 batch
# 768 img procesed out of 13744, taken 0.77 sec per 1 batch
# 928 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1088 img procesed out of 13744, taken 0.76 sec per 1 batch
# 1248 img procesed out of 13744, taken 0.79 sec per 1 batch
# 1408 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1568 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1728 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1888 img procesed out of 13744, taken 0.71 sec per 1 batch
# 2048 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2208 img procesed out of 13744, taken 0.75 sec per 1 batch
# 2368 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2528 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2688 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2848 img procesed out of 13744, taken 0.77 sec per 1 batch
# 3008 img procesed out of 13744, taken 0.77 sec per 1 batch
# 3168 img procesed out of 13744, taken 0.77 sec per 1 batch
# 3328 img procesed out of 13744, taken 0.73 sec per 1 batch
# 3488 img procesed out of 13744, taken 0.76 sec per 1 batch
# 3648 img procesed out of 13744, taken 0.77 sec per 1 batch
# 3808 img procesed out of 13744, taken 0.72 sec per 1 batch
# 3968 img procesed out of 13744, taken 0.80 sec per 1 batch
# 4128 img procesed out of 13744, taken 0.79 sec per 1 batch
# 4288 img procesed out of 13744, taken 0.78 sec per 1 batch
# 4448 img procesed out of 13744, taken 0.77 sec per 1 batch
# 4608 img procesed out of 13744, taken 0.72 sec per 1 batch
# 4768 img procesed out of 13744, taken 0.78 sec per 1 batch
# 4928 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5088 img procesed out of 13744, taken 0.74 sec per 1 batch
# 5248 img procesed out of 13744, taken 0.79 sec per 1 batch
# 5408 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5568 img procesed out of 13744, taken 0.72 sec per 1 batch
# 5728 img procesed out of 13744, taken 0.76 sec per 1 batch
# 5888 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6048 img procesed out of 13744, taken 0.76 sec per 1 batch
# 6208 img procesed out of 13744, taken 0.74 sec per 1 batch
# 6368 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6528 img procesed out of 13744, taken 0.79 sec per 1 batch
# 6688 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6848 img procesed out of 13744, taken 0.73 sec per 1 batch
# 7008 img procesed out of 13744, taken 0.77 sec per 1 batch
# 7168 img procesed out of 13744, taken 0.77 sec per 1 batch
# 7328 img procesed out of 13744, taken 0.72 sec per 1 batch
# 7488 img procesed out of 13744, taken 0.78 sec per 1 batch
# 7648 img procesed out of 13744, taken 0.72 sec per 1 batch
# 7808 img procesed out of 13744, taken 0.77 sec per 1 batch
# 7968 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8128 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8288 img procesed out of 13744, taken 0.77 sec per 1 batch
# 8448 img procesed out of 13744, taken 0.79 sec per 1 batch
# 8608 img procesed out of 13744, taken 0.77 sec per 1 batch
# 8768 img procesed out of 13744, taken 0.77 sec per 1 batch
# 8928 img procesed out of 13744, taken 0.78 sec per 1 batch
# 9088 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9248 img procesed out of 13744, taken 0.73 sec per 1 batch
# 9408 img procesed out of 13744, taken 0.74 sec per 1 batch
# 9568 img procesed out of 13744, taken 0.72 sec per 1 batch
# 9728 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9888 img procesed out of 13744, taken 0.75 sec per 1 batch
# 10048 img procesed out of 13744, taken 0.78 sec per 1 batch
# 10208 img procesed out of 13744, taken 0.72 sec per 1 batch
# 10368 img procesed out of 13744, taken 0.77 sec per 1 batch
# 10528 img procesed out of 13744, taken 0.71 sec per 1 batch
# 10688 img procesed out of 13744, taken 0.78 sec per 1 batch
# 10848 img procesed out of 13744, taken 0.79 sec per 1 batch
# 11008 img procesed out of 13744, taken 0.76 sec per 1 batch
# 11168 img procesed out of 13744, taken 0.77 sec per 1 batch
# 11328 img procesed out of 13744, taken 0.79 sec per 1 batch
# 11488 img procesed out of 13744, taken 0.77 sec per 1 batch
# 11648 img procesed out of 13744, taken 0.77 sec per 1 batch
# 11808 img procesed out of 13744, taken 0.73 sec per 1 batch
# 11968 img procesed out of 13744, taken 0.77 sec per 1 batch
# 12128 img procesed out of 13744, taken 0.77 sec per 1 batch
# 12288 img procesed out of 13744, taken 0.76 sec per 1 batch
# 12448 img procesed out of 13744, taken 0.76 sec per 1 batch
# 12608 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12768 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12928 img procesed out of 13744, taken 0.80 sec per 1 batch
# 13088 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13248 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13408 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13568 img procesed out of 13744, taken 0.77 sec per 1 batch
# 13728 img procesed out of 13744, taken 0.75 sec per 1 batch
# End of epoch 19 / 25 	 Time Taken: 2696.59 sec
# learning rate = 0.0003000
# 144 img procesed out of 13744, taken 0.73 sec per 1 batch
# 304 img procesed out of 13744, taken 0.78 sec per 1 batch
# 464 img procesed out of 13744, taken 0.79 sec per 1 batch
# 624 img procesed out of 13744, taken 0.79 sec per 1 batch
# 784 img procesed out of 13744, taken 0.73 sec per 1 batch
# 944 img procesed out of 13744, taken 0.78 sec per 1 batch
# 1104 img procesed out of 13744, taken 0.76 sec per 1 batch
# 1264 img procesed out of 13744, taken 0.79 sec per 1 batch
# 1424 img procesed out of 13744, taken 0.78 sec per 1 batch
# 1584 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1744 img procesed out of 13744, taken 0.77 sec per 1 batch
# 1904 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2064 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2224 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2384 img procesed out of 13744, taken 0.76 sec per 1 batch
# 2544 img procesed out of 13744, taken 0.78 sec per 1 batch
# 2704 img procesed out of 13744, taken 0.77 sec per 1 batch
# 2864 img procesed out of 13744, taken 0.77 sec per 1 batch
# 3024 img procesed out of 13744, taken 0.77 sec per 1 batch
# 3184 img procesed out of 13744, taken 0.79 sec per 1 batch
# 3344 img procesed out of 13744, taken 0.78 sec per 1 batch
# 3504 img procesed out of 13744, taken 0.76 sec per 1 batch
# 3664 img procesed out of 13744, taken 0.74 sec per 1 batch
# 3824 img procesed out of 13744, taken 0.73 sec per 1 batch
# 3984 img procesed out of 13744, taken 0.79 sec per 1 batch
# 4144 img procesed out of 13744, taken 0.79 sec per 1 batch
# 4304 img procesed out of 13744, taken 0.79 sec per 1 batch
# 4464 img procesed out of 13744, taken 0.74 sec per 1 batch
# 4624 img procesed out of 13744, taken 0.78 sec per 1 batch
# 4784 img procesed out of 13744, taken 0.74 sec per 1 batch
# 4944 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5104 img procesed out of 13744, taken 0.78 sec per 1 batch
# 5264 img procesed out of 13744, taken 0.70 sec per 1 batch
# 5424 img procesed out of 13744, taken 0.77 sec per 1 batch
# 5584 img procesed out of 13744, taken 0.78 sec per 1 batch
# 5744 img procesed out of 13744, taken 0.80 sec per 1 batch
# 5904 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6064 img procesed out of 13744, taken 0.79 sec per 1 batch
# 6224 img procesed out of 13744, taken 0.75 sec per 1 batch
# 6384 img procesed out of 13744, taken 0.81 sec per 1 batch
# 6544 img procesed out of 13744, taken 0.77 sec per 1 batch
# 6704 img procesed out of 13744, taken 0.76 sec per 1 batch
# 6864 img procesed out of 13744, taken 0.78 sec per 1 batch
# 7024 img procesed out of 13744, taken 0.79 sec per 1 batch
# 7184 img procesed out of 13744, taken 0.78 sec per 1 batch
# 7344 img procesed out of 13744, taken 0.73 sec per 1 batch
# 7504 img procesed out of 13744, taken 0.74 sec per 1 batch
# 7664 img procesed out of 13744, taken 0.79 sec per 1 batch
# 7824 img procesed out of 13744, taken 0.72 sec per 1 batch
# 7984 img procesed out of 13744, taken 0.73 sec per 1 batch
# 8144 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8304 img procesed out of 13744, taken 0.79 sec per 1 batch
# 8464 img procesed out of 13744, taken 0.81 sec per 1 batch
# 8624 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8784 img procesed out of 13744, taken 0.78 sec per 1 batch
# 8944 img procesed out of 13744, taken 0.78 sec per 1 batch
# 9104 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9264 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9424 img procesed out of 13744, taken 0.78 sec per 1 batch
# 9584 img procesed out of 13744, taken 0.78 sec per 1 batch
# 9744 img procesed out of 13744, taken 0.77 sec per 1 batch
# 9904 img procesed out of 13744, taken 0.78 sec per 1 batch
# 10064 img procesed out of 13744, taken 0.75 sec per 1 batch
# 10224 img procesed out of 13744, taken 0.79 sec per 1 batch
# 10384 img procesed out of 13744, taken 0.73 sec per 1 batch
# 10544 img procesed out of 13744, taken 0.78 sec per 1 batch
# 10704 img procesed out of 13744, taken 0.72 sec per 1 batch
# 10864 img procesed out of 13744, taken 0.78 sec per 1 batch
# 11024 img procesed out of 13744, taken 0.77 sec per 1 batch
# 11184 img procesed out of 13744, taken 0.77 sec per 1 batch
# 11344 img procesed out of 13744, taken 0.77 sec per 1 batch
# 11504 img procesed out of 13744, taken 0.78 sec per 1 batch
# 11664 img procesed out of 13744, taken 0.78 sec per 1 batch
# 11824 img procesed out of 13744, taken 0.79 sec per 1 batch
# 11984 img procesed out of 13744, taken 0.79 sec per 1 batch
# 12144 img procesed out of 13744, taken 0.77 sec per 1 batch
# 12304 img procesed out of 13744, taken 0.76 sec per 1 batch
# 12464 img procesed out of 13744, taken 0.78 sec per 1 batch
# 12624 img procesed out of 13744, taken 0.77 sec per 1 batch
# 12784 img procesed out of 13744, taken 0.79 sec per 1 batch
# 12944 img procesed out of 13744, taken 0.78 sec per 1 batch
# 13104 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13264 img procesed out of 13744, taken 0.79 sec per 1 batch
# 13424 img procesed out of 13744, taken 0.74 sec per 1 batch
# 13584 img procesed out of 13744, taken 0.77 sec per 1 batch
# 13744 img procesed out of 13744, taken 0.78 sec per 1 batch
# saving the model at the end of epoch 20, iters 68720
# End of epoch 20 / 25 	 Time Taken: 2717.32 sec
# learning rate = 0.0002500
# 160 img procesed out of 13744, taken 0.78 sec per 1 batch
# 320 img procesed out of 13744, taken 0.79 sec per 1 batch

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
# --gpu_ids 2,3\
# --name try_second_cycle_upconv\
# --use_second_cycle\
# --gan_mode lsgan\
# --upsampling_type upconv\
# --n_blocks 9\
# --n_downsampling 2\
# --ngf_depth 32\
# --ngf_img 32\
# --ndf 64\
# --netD n_layers\
# --n_layers_D 3\
# --l_depth_A_begin 0\
# --l_depth_A_end 0\
# --l_depth_B_begin 0\
# --l_depth_B_end 0\
# --l_depth_max_iter 10000\
# --l_cycle_A_begin 10.0\
# --l_cycle_A_end 10.0\
# --l_cycle_B_begin 10.0\
# --l_cycle_B_end 10.0\
# --l_identity 0\
# --max_dataset_size 20000\
# --data_shuffle\
# --batch_size 8\
# --lr_D 0.0002\
# --lr_G 0.0001\
# --num_iter_gen 1\
# --norm instance\
# --init_type normal\
# --beta1 0.5\
# --img_freq 40\
# --loss_freq 30\
# --save_epoch_freq 3\
# --n_epochs 10\
# --n_epochs_decay 5
# Out:
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 5]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#              data_shuffle: True                          	[default: False]
#                  dataroot: /all_data/hdd/un_depth/semi/sample
#              dataset_mode: semi_cycle
#          disc_for_normals: False
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 2,3                           	[default: 2]
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0                          	[default: 1.0]
#             l_cycle_A_end: 10.0                          	[default: 1.0]
#           l_cycle_B_begin: 10.0                          	[default: 1.0]
#             l_cycle_B_end: 10.0                          	[default: 1.0]
#           l_depth_A_begin: 0.0                           	[default: 1.0]
#             l_depth_A_end: 0.0                           	[default: 1.0]
#           l_depth_B_begin: 0.0                           	[default: 1.0]
#             l_depth_B_end: 0.0                           	[default: 1.0]
#          l_depth_max_iter: 10000                         	[default: 20000]
#                l_identity: 0.0                           	[default: 1.0]
# l_reconstruction_semantic: 1.0
#                load_epoch: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 480
#               load_size_w: 640
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0002
#                      lr_G: 0.0001                        	[default: 0.0002]
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 20000                         	[default: inf]
#              max_distance: 8000.0
#                     model: semi_cycle_gan
#                  n_blocks: 9
#            n_downsampling: 2                             	[default: 3]
#                  n_epochs: 10                            	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: try_second_cycle_upconv       	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32                            	[default: 20]
#                   ngf_img: 32
#                      norm: instance
#              num_iter_dis: 1
#              num_iter_gen: 1
#               num_workers: 4
#             old_generator: False
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 3                             	[default: 10]
#           upsampling_type: upconv
#                  use_blur: False
#          use_second_cycle: True                          	[default: False]
#              use_semantic: False
#                   verbose: False
# ----------------- End -------------------
# wandb: Tracking run with wandb version 0.9.7
# wandb: Wandb version 0.10.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Run data is saved locally in wandb/run-20201017_220028-162ui8z7
# wandb: Syncing run try_second_cycle_upconv
# wandb: ⭐️ View project at https://app.wandb.ai/maxs/depth_super_res
# wandb: 🚀 View run at https://app.wandb.ai/maxs/depth_super_res/runs/162ui8z7
# wandb: Run `wandb off` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 20000
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [SemiCycleGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.328 M
# [Network netG_B] Total number of parameters : 11.652 M
# [Network netD_A_depth] Total number of parameters : 2.763 M
# [Network netD_B_depth] Total number of parameters : 2.763 M
# -----------------------------------------------

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
# --model A2B\
# --gpu_ids 0\
# --name a2b_uptranspose\
# --gan_mode lsgan\
# --upsampling_type transpose\
# --n_blocks 9\
# --n_downsampling 3\
# --ngf_depth 20\
# --ngf_img 32\
# --ndf 64\
# --netD n_layers\
# --n_layers_D 3\
# --l_depth_A_begin 1\
# --l_depth_A_end 1\
# --l_gan_loss 2\
# --l_depth_max_iter 30000\
# --max_dataset_size 20000\
# --batch_size 7\
# --lr_D 0.0001\
# --lr_G 0.0005\
# --num_iter_gen 3\
# --norm instance\
# --init_type xavier\
# --beta1 0.5\
# --img_freq 40\
# --loss_freq 30\
# --save_epoch_freq 2\
# --n_epochs 20\
# --n_epochs_decay 5\
# # --netG_d2e unet_256\
# # --net_d2e_weights './checkpoints/depth_edge_unet_1.5_weight_binatyloss/last_netG_B.pth'\
