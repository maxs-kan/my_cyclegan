# %%
import os
os.chdir('/workspace/my_cyclegan')

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
--gpu_ids 2,3\
--name try_second_cycle_upconv\
--use_second_cycle\
--gan_mode lsgan\
--upsampling_type upconv\
--n_blocks 9\
--n_downsampling 2\
--ngf_depth 32\
--ngf_img 32\
--ndf 64\
--netD n_layers\
--n_layers_D 3\
--l_depth_A_begin 0\
--l_depth_A_end 0\
--l_depth_B_begin 0\
--l_depth_B_end 0\
--l_depth_max_iter 10000\
--l_cycle_A_begin 10.0\
--l_cycle_A_end 10.0\
--l_cycle_B_begin 10.0\
--l_cycle_B_end 10.0\
--l_identity 0\
--max_dataset_size 20000\
--data_shuffle\
--batch_size 8\
--lr_D 0.0002\
--lr_G 0.0001\
--num_iter_gen 1\
--norm instance\
--init_type normal\
--beta1 0.5\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 3\
--n_epochs 10\
--n_epochs_decay 5
# Out:
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 5]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#              data_shuffle: True                          	[default: False]
#                  dataroot: /all_data/hdd/un_depth/semi/sample
#              dataset_mode: semi_cycle
#          disc_for_normals: False
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 2,3                           	[default: 2]
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0                          	[default: 1.0]
#             l_cycle_A_end: 10.0                          	[default: 1.0]
#           l_cycle_B_begin: 10.0                          	[default: 1.0]
#             l_cycle_B_end: 10.0                          	[default: 1.0]
#           l_depth_A_begin: 0.0                           	[default: 1.0]
#             l_depth_A_end: 0.0                           	[default: 1.0]
#           l_depth_B_begin: 0.0                           	[default: 1.0]
#             l_depth_B_end: 0.0                           	[default: 1.0]
#          l_depth_max_iter: 10000                         	[default: 20000]
#                l_identity: 0.0                           	[default: 1.0]
# l_reconstruction_semantic: 1.0
#                load_epoch: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 480
#               load_size_w: 640
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0002
#                      lr_G: 0.0001                        	[default: 0.0002]
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 20000                         	[default: inf]
#              max_distance: 8000.0
#                     model: semi_cycle_gan
#                  n_blocks: 9
#            n_downsampling: 2                             	[default: 3]
#                  n_epochs: 10                            	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: try_second_cycle_upconv       	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32                            	[default: 20]
#                   ngf_img: 32
#                      norm: instance
#              num_iter_dis: 1
#              num_iter_gen: 1
#               num_workers: 4
#             old_generator: False
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 3                             	[default: 10]
#           upsampling_type: upconv
#                  use_blur: False
#          use_second_cycle: True                          	[default: False]
#              use_semantic: False
#                   verbose: False
# ----------------- End -------------------
# wandb: Tracking run with wandb version 0.9.7
# wandb: Wandb version 0.10.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Run data is saved locally in wandb/run-20201017_220028-162ui8z7
# wandb: Syncing run try_second_cycle_upconv
# wandb: ⭐️ View project at https://app.wandb.ai/maxs/depth_super_res
# wandb: 🚀 View run at https://app.wandb.ai/maxs/depth_super_res/runs/162ui8z7
# wandb: Run `wandb off` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 20000
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [SemiCycleGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.328 M
# [Network netG_B] Total number of parameters : 11.652 M
# [Network netD_A_depth] Total number of parameters : 2.763 M
# [Network netD_B_depth] Total number of parameters : 2.763 M
# -----------------------------------------------

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
--model A2B\
--gpu_ids 0\
--name a2b_uptranspose\
--gan_mode lsgan\
--upsampling_type transpose\
--n_blocks 9\
--n_downsampling 3\
--ngf_depth 20\
--ngf_img 32\
--ndf 64\
--netD n_layers\
--n_layers_D 3\
--l_depth_A_begin 1\
--l_depth_A_end 1\
--l_gan_loss 2\
--l_depth_max_iter 30000\
--max_dataset_size 20000\
--batch_size 7\
--lr_D 0.0001\
--lr_G 0.0005\
--num_iter_gen 3\
--norm instance\
--init_type xavier\
--beta1 0.5\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 2\
--n_epochs 20\
--n_epochs_decay 5\
# --netG_d2e unet_256\
# --net_d2e_weights './checkpoints/depth_edge_unet_1.5_weight_binatyloss/last_netG_B.pth'\
# Out:
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 5]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#              data_shuffle: True
#                  dataroot: /all_data/hdd/un_depth/semi/sample
#              dataset_mode: semi_cycle
#          disc_for_normals: False
#                   dropout: True
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0                             	[default: 2]
#                  img_freq: 40                            	[default: 1]
#                 init_type: xavier                        	[default: normal]
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_depth_A_begin: 1.0
#             l_depth_A_end: 1.0
#          l_depth_max_iter: 30000                         	[default: 20000]
#                l_gan_loss: 2.0                           	[default: 1.0]
#                load_epoch: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 480
#               load_size_w: 640
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0001                        	[default: 0.0002]
#                      lr_G: 0.0005                        	[default: 0.0002]
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 20000                         	[default: inf]
#              max_distance: 8000.0
#                     model: A2B                           	[default: semi_cycle_gan]
#                  n_blocks: 9
#            n_downsampling: 3
#                  n_epochs: 20                            	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: a2b_uptranspose               	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 20
#                   ngf_img: 32
#                      norm: instance
#              num_iter_dis: 1
#              num_iter_gen: 3                             	[default: 1]
#               num_workers: 8
#             old_generator: False
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 2                             	[default: 10]
#           upsampling_type: transpose                     	[default: upconv]
#              use_semantic: False
#                   verbose: False
# ----------------- End -------------------
# wandb: Tracking run with wandb version 0.9.7
# wandb: Wandb version 0.10.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Run data is saved locally in wandb/run-20201013_150633-34lu5ywm
# wandb: Syncing run a2b_uptranspose
# wandb: ⭐️ View project at https://app.wandb.ai/maxs/depth_super_res
# wandb: 🚀 View run at https://app.wandb.ai/maxs/depth_super_res/runs/34lu5ywm
# wandb: Run `wandb off` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 20000
# initialize network with xavier
# initialize network with xavier
# model [A2BModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 29.463 M
# [Network netD_A] Total number of parameters : 2.763 M
# -----------------------------------------------
# 320 img procesed out of 20000, taken 0.7483611106872559 sec per 1 batch
# 640 img procesed out of 20000, taken 0.7483422756195068 sec per 1 batch
# 960 img procesed out of 20000, taken 0.892728328704834 sec per 1 batch
# 1280 img procesed out of 20000, taken 0.7504351139068604 sec per 1 batch
# 1600 img procesed out of 20000, taken 0.7495005130767822 sec per 1 batch
# 1920 img procesed out of 20000, taken 0.8863446712493896 sec per 1 batch
# 2240 img procesed out of 20000, taken 0.750248908996582 sec per 1 batch
# 2560 img procesed out of 20000, taken 0.7550632953643799 sec per 1 batch
# 2880 img procesed out of 20000, taken 0.8990471363067627 sec per 1 batch
# 3200 img procesed out of 20000, taken 0.7577478885650635 sec per 1 batch
# 3520 img procesed out of 20000, taken 0.7545642852783203 sec per 1 batch
# 3840 img procesed out of 20000, taken 0.8926997184753418 sec per 1 batch
# 4160 img procesed out of 20000, taken 0.7553894519805908 sec per 1 batch
# 4480 img procesed out of 20000, taken 0.7555603981018066 sec per 1 batch
# 4800 img procesed out of 20000, taken 0.9297401905059814 sec per 1 batch
# 5120 img procesed out of 20000, taken 0.755962610244751 sec per 1 batch
# 5440 img procesed out of 20000, taken 0.7570192813873291 sec per 1 batch
# 5760 img procesed out of 20000, taken 0.8935604095458984 sec per 1 batch
# 6080 img procesed out of 20000, taken 0.7563421726226807 sec per 1 batch
# 6400 img procesed out of 20000, taken 0.757910966873169 sec per 1 batch
# 6720 img procesed out of 20000, taken 0.8983571529388428 sec per 1 batch
# 7040 img procesed out of 20000, taken 0.7584483623504639 sec per 1 batch
# 7360 img procesed out of 20000, taken 0.7598905563354492 sec per 1 batch
# 7680 img procesed out of 20000, taken 0.925858736038208 sec per 1 batch
# 8000 img procesed out of 20000, taken 1.0225732326507568 sec per 1 batch
# 8320 img procesed out of 20000, taken 0.7591884136199951 sec per 1 batch
# 8640 img procesed out of 20000, taken 0.8941402435302734 sec per 1 batch
# 8960 img procesed out of 20000, taken 0.7586467266082764 sec per 1 batch
# 9280 img procesed out of 20000, taken 0.7598366737365723 sec per 1 batch
# 9600 img procesed out of 20000, taken 0.8966450691223145 sec per 1 batch
# 9920 img procesed out of 20000, taken 0.7555139064788818 sec per 1 batch
# 10240 img procesed out of 20000, taken 0.7608377933502197 sec per 1 batch
# 10560 img procesed out of 20000, taken 0.9214131832122803 sec per 1 batch
# 10880 img procesed out of 20000, taken 0.7620425224304199 sec per 1 batch
# 11200 img procesed out of 20000, taken 0.7589998245239258 sec per 1 batch
# 11520 img procesed out of 20000, taken 0.8985342979431152 sec per 1 batch
# 11840 img procesed out of 20000, taken 0.761486291885376 sec per 1 batch
# 12160 img procesed out of 20000, taken 0.7595126628875732 sec per 1 batch
# 12480 img procesed out of 20000, taken 0.9009623527526855 sec per 1 batch
# 12800 img procesed out of 20000, taken 0.7590861320495605 sec per 1 batch
# 13120 img procesed out of 20000, taken 0.7584173679351807 sec per 1 batch
# 13440 img procesed out of 20000, taken 0.9036035537719727 sec per 1 batch
# 13760 img procesed out of 20000, taken 0.7588701248168945 sec per 1 batch
# 14080 img procesed out of 20000, taken 0.7601737976074219 sec per 1 batch
# 14400 img procesed out of 20000, taken 0.9316873550415039 sec per 1 batch
# 14720 img procesed out of 20000, taken 0.759026050567627 sec per 1 batch
# 15040 img procesed out of 20000, taken 0.7591567039489746 sec per 1 batch
# 15360 img procesed out of 20000, taken 0.9279723167419434 sec per 1 batch
# 15680 img procesed out of 20000, taken 0.7586417198181152 sec per 1 batch
# 16000 img procesed out of 20000, taken 1.0327579975128174 sec per 1 batch
# 16320 img procesed out of 20000, taken 0.902947187423706 sec per 1 batch
# 16640 img procesed out of 20000, taken 0.7584631443023682 sec per 1 batch
# 16960 img procesed out of 20000, taken 0.759624719619751 sec per 1 batch
# 17280 img procesed out of 20000, taken 0.9285125732421875 sec per 1 batch
# 17600 img procesed out of 20000, taken 0.7627556324005127 sec per 1 batch
# 17920 img procesed out of 20000, taken 0.7603318691253662 sec per 1 batch
# 18240 img procesed out of 20000, taken 0.9373018741607666 sec per 1 batch
# 18560 img procesed out of 20000, taken 0.7572886943817139 sec per 1 batch
# 18880 img procesed out of 20000, taken 0.7606234550476074 sec per 1 batch
# 19200 img procesed out of 20000, taken 0.904198169708252 sec per 1 batch
# 19520 img procesed out of 20000, taken 0.7612483501434326 sec per 1 batch
# 19840 img procesed out of 20000, taken 0.7586307525634766 sec per 1 batch
# End of epoch 1 / 25 	 Time Taken: 2094 sec
# learning rate = 0.0005000
# 160 img procesed out of 20000, taken 0.9248795509338379 sec per 1 batch
# 480 img procesed out of 20000, taken 0.7617707252502441 sec per 1 batch
# 800 img procesed out of 20000, taken 0.759404182434082 sec per 1 batch
# 1120 img procesed out of 20000, taken 0.9204301834106445 sec per 1 batch
# 1440 img procesed out of 20000, taken 0.7589116096496582 sec per 1 batch
# 1760 img procesed out of 20000, taken 0.7595655918121338 sec per 1 batch
# 2080 img procesed out of 20000, taken 0.9231071472167969 sec per 1 batch
# 2400 img procesed out of 20000, taken 0.7568249702453613 sec per 1 batch
# 2720 img procesed out of 20000, taken 0.761375904083252 sec per 1 batch
# 3040 img procesed out of 20000, taken 0.9017374515533447 sec per 1 batch
# 3360 img procesed out of 20000, taken 0.7587888240814209 sec per 1 batch
# 3680 img procesed out of 20000, taken 0.7608859539031982 sec per 1 batch
# 4000 img procesed out of 20000, taken 1.1171700954437256 sec per 1 batch
# 4320 img procesed out of 20000, taken 0.7607331275939941 sec per 1 batch
# 4640 img procesed out of 20000, taken 0.7631573677062988 sec per 1 batch
# 4960 img procesed out of 20000, taken 0.9053716659545898 sec per 1 batch
# 5280 img procesed out of 20000, taken 0.7598247528076172 sec per 1 batch
# 5600 img procesed out of 20000, taken 0.7574672698974609 sec per 1 batch
# 5920 img procesed out of 20000, taken 0.9268372058868408 sec per 1 batch
# 6240 img procesed out of 20000, taken 0.7619402408599854 sec per 1 batch
# 6560 img procesed out of 20000, taken 0.7589502334594727 sec per 1 batch
# 6880 img procesed out of 20000, taken 0.9441311359405518 sec per 1 batch
# 7200 img procesed out of 20000, taken 0.7631528377532959 sec per 1 batch
# 7520 img procesed out of 20000, taken 0.7595994472503662 sec per 1 batch
# 7840 img procesed out of 20000, taken 0.9022073745727539 sec per 1 batch
# 8160 img procesed out of 20000, taken 0.7644398212432861 sec per 1 batch
# 8480 img procesed out of 20000, taken 0.7620406150817871 sec per 1 batch
# 8800 img procesed out of 20000, taken 0.9003880023956299 sec per 1 batch
# 9120 img procesed out of 20000, taken 0.7608423233032227 sec per 1 batch
# 9440 img procesed out of 20000, taken 0.765167236328125 sec per 1 batch
# 9760 img procesed out of 20000, taken 0.9174730777740479 sec per 1 batch
# 10080 img procesed out of 20000, taken 0.761864423751831 sec per 1 batch
# 10400 img procesed out of 20000, taken 0.7621827125549316 sec per 1 batch
# 10720 img procesed out of 20000, taken 0.906670093536377 sec per 1 batch
# 11040 img procesed out of 20000, taken 0.760127067565918 sec per 1 batch
# 11360 img procesed out of 20000, taken 0.7598588466644287 sec per 1 batch
# 11680 img procesed out of 20000, taken 0.9045364856719971 sec per 1 batch
# 12000 img procesed out of 20000, taken 1.0941157341003418 sec per 1 batch
# 12320 img procesed out of 20000, taken 0.7687575817108154 sec per 1 batch
# 12640 img procesed out of 20000, taken 0.9350399971008301 sec per 1 batch
# 12960 img procesed out of 20000, taken 0.7623379230499268 sec per 1 batch
# 13280 img procesed out of 20000, taken 0.7592065334320068 sec per 1 batch
# 13600 img procesed out of 20000, taken 0.9261815547943115 sec per 1 batch
# 13920 img procesed out of 20000, taken 0.7624430656433105 sec per 1 batch
# 14240 img procesed out of 20000, taken 0.7706034183502197 sec per 1 batch
# 14560 img procesed out of 20000, taken 0.9553139209747314 sec per 1 batch
# 14880 img procesed out of 20000, taken 0.7647454738616943 sec per 1 batch
# 15200 img procesed out of 20000, taken 0.7782268524169922 sec per 1 batch
# 15520 img procesed out of 20000, taken 0.9050424098968506 sec per 1 batch
# 15840 img procesed out of 20000, taken 0.7600090503692627 sec per 1 batch
# 16160 img procesed out of 20000, taken 0.7720065116882324 sec per 1 batch
# 16480 img procesed out of 20000, taken 0.9042878150939941 sec per 1 batch
# 16800 img procesed out of 20000, taken 0.757866621017456 sec per 1 batch
# 17120 img procesed out of 20000, taken 0.7612102031707764 sec per 1 batch
# 17440 img procesed out of 20000, taken 0.912621021270752 sec per 1 batch
# 17760 img procesed out of 20000, taken 0.7848258018493652 sec per 1 batch
# 18080 img procesed out of 20000, taken 0.7650818824768066 sec per 1 batch
# 18400 img procesed out of 20000, taken 0.9040703773498535 sec per 1 batch
# 18720 img procesed out of 20000, taken 0.760246753692627 sec per 1 batch
# 19040 img procesed out of 20000, taken 0.7612664699554443 sec per 1 batch
# 19360 img procesed out of 20000, taken 0.9014513492584229 sec per 1 batch
# 19680 img procesed out of 20000, taken 0.7714722156524658 sec per 1 batch
# 20000 img procesed out of 20000, taken 1.1321122646331787 sec per 1 batch
# saving the model at the end of epoch 2, iters 5000
# End of epoch 2 / 25 	 Time Taken: 2106 sec
# learning rate = 0.0005000
# 320 img procesed out of 20000, taken 0.9207887649536133 sec per 1 batch
# 640 img procesed out of 20000, taken 0.7613098621368408 sec per 1 batch
# 960 img procesed out of 20000, taken 0.7923903465270996 sec per 1 batch
# 1280 img procesed out of 20000, taken 0.9151098728179932 sec per 1 batch
# 1600 img procesed out of 20000, taken 0.7589685916900635 sec per 1 batch
# 1920 img procesed out of 20000, taken 0.7882568836212158 sec per 1 batch
# 2240 img procesed out of 20000, taken 0.9332242012023926 sec per 1 batch
# 2560 img procesed out of 20000, taken 0.7655057907104492 sec per 1 batch
# 2880 img procesed out of 20000, taken 0.7863719463348389 sec per 1 batch
# 3200 img procesed out of 20000, taken 0.9601936340332031 sec per 1 batch
# 3520 img procesed out of 20000, taken 0.7643811702728271 sec per 1 batch
# 3840 img procesed out of 20000, taken 0.7597057819366455 sec per 1 batch
# 4160 img procesed out of 20000, taken 0.9256184101104736 sec per 1 batch
# 4480 img procesed out of 20000, taken 0.7629587650299072 sec per 1 batch
# 4800 img procesed out of 20000, taken 0.7638070583343506 sec per 1 batch
# 5120 img procesed out of 20000, taken 0.9230930805206299 sec per 1 batch
# 5440 img procesed out of 20000, taken 0.784494161605835 sec per 1 batch
# 5760 img procesed out of 20000, taken 0.7619483470916748 sec per 1 batch
# 6080 img procesed out of 20000, taken 0.9154975414276123 sec per 1 batch
# 6400 img procesed out of 20000, taken 0.7628965377807617 sec per 1 batch
# 6720 img procesed out of 20000, taken 0.7625894546508789 sec per 1 batch
# 7040 img procesed out of 20000, taken 0.9015660285949707 sec per 1 batch
# 7360 img procesed out of 20000, taken 0.7625491619110107 sec per 1 batch
# 7680 img procesed out of 20000, taken 0.7681214809417725 sec per 1 batch
# 8000 img procesed out of 20000, taken 1.1726539134979248 sec per 1 batch
# 8320 img procesed out of 20000, taken 0.8639547824859619 sec per 1 batch
# 8640 img procesed out of 20000, taken 0.7649848461151123 sec per 1 batch
# 8960 img procesed out of 20000, taken 0.9258060455322266 sec per 1 batch
# 9280 img procesed out of 20000, taken 0.7649776935577393 sec per 1 batch
# 9600 img procesed out of 20000, taken 0.7603771686553955 sec per 1 batch
# 9920 img procesed out of 20000, taken 0.9234979152679443 sec per 1 batch
# 10240 img procesed out of 20000, taken 0.7623291015625 sec per 1 batch
# 10560 img procesed out of 20000, taken 0.7612855434417725 sec per 1 batch
# 10880 img procesed out of 20000, taken 0.9114797115325928 sec per 1 batch
# 11200 img procesed out of 20000, taken 0.7624619007110596 sec per 1 batch
# 11520 img procesed out of 20000, taken 0.760974645614624 sec per 1 batch
# 11840 img procesed out of 20000, taken 0.903287410736084 sec per 1 batch
# 12160 img procesed out of 20000, taken 0.7693638801574707 sec per 1 batch
# 12480 img procesed out of 20000, taken 0.7863705158233643 sec per 1 batch
# 12800 img procesed out of 20000, taken 0.9177746772766113 sec per 1 batch
# 13120 img procesed out of 20000, taken 0.7622847557067871 sec per 1 batch
# 13440 img procesed out of 20000, taken 0.7726619243621826 sec per 1 batch
# 13760 img procesed out of 20000, taken 0.9142274856567383 sec per 1 batch
# 14080 img procesed out of 20000, taken 0.7634832859039307 sec per 1 batch
# 14400 img procesed out of 20000, taken 0.7629191875457764 sec per 1 batch
# 14720 img procesed out of 20000, taken 0.933568000793457 sec per 1 batch
# 15040 img procesed out of 20000, taken 0.7610146999359131 sec per 1 batch
# 15360 img procesed out of 20000, taken 0.7688889503479004 sec per 1 batch
# 15680 img procesed out of 20000, taken 0.8980870246887207 sec per 1 batch
# 16000 img procesed out of 20000, taken 1.0612401962280273 sec per 1 batch
# 16320 img procesed out of 20000, taken 0.7703533172607422 sec per 1 batch
# 16640 img procesed out of 20000, taken 0.9181411266326904 sec per 1 batch
# 16960 img procesed out of 20000, taken 0.7640805244445801 sec per 1 batch
# 17280 img procesed out of 20000, taken 0.7598879337310791 sec per 1 batch
# 17600 img procesed out of 20000, taken 0.8964457511901855 sec per 1 batch
# 17920 img procesed out of 20000, taken 0.7631964683532715 sec per 1 batch
# 18240 img procesed out of 20000, taken 0.7618081569671631 sec per 1 batch
# 18560 img procesed out of 20000, taken 0.898033618927002 sec per 1 batch
# 18880 img procesed out of 20000, taken 0.7585937976837158 sec per 1 batch
# 19200 img procesed out of 20000, taken 0.7569832801818848 sec per 1 batch
# 19520 img procesed out of 20000, taken 0.9074492454528809 sec per 1 batch
# 19840 img procesed out of 20000, taken 0.7609741687774658 sec per 1 batch
# End of epoch 3 / 25 	 Time Taken: 2108 sec
# learning rate = 0.0005000
# 160 img procesed out of 20000, taken 0.758220911026001 sec per 1 batch
# 480 img procesed out of 20000, taken 0.9012939929962158 sec per 1 batch
# 800 img procesed out of 20000, taken 0.76127028465271 sec per 1 batch
# 1120 img procesed out of 20000, taken 0.7569911479949951 sec per 1 batch
# 1440 img procesed out of 20000, taken 0.9032318592071533 sec per 1 batch
# 1760 img procesed out of 20000, taken 0.7587730884552002 sec per 1 batch
# 2080 img procesed out of 20000, taken 0.7569208145141602 sec per 1 batch
# 2400 img procesed out of 20000, taken 0.9477310180664062 sec per 1 batch
# 2720 img procesed out of 20000, taken 0.7589707374572754 sec per 1 batch
# 3040 img procesed out of 20000, taken 0.7568187713623047 sec per 1 batch
# 3360 img procesed out of 20000, taken 0.9009678363800049 sec per 1 batch
# 3680 img procesed out of 20000, taken 0.7607722282409668 sec per 1 batch
# 4000 img procesed out of 20000, taken 1.0090670585632324 sec per 1 batch
# 4320 img procesed out of 20000, taken 0.8952012062072754 sec per 1 batch
# 4640 img procesed out of 20000, taken 0.7626986503601074 sec per 1 batch
# 4960 img procesed out of 20000, taken 0.7578678131103516 sec per 1 batch
# 5280 img procesed out of 20000, taken 0.9031977653503418 sec per 1 batch
# 5600 img procesed out of 20000, taken 0.7626402378082275 sec per 1 batch
# 5920 img procesed out of 20000, taken 0.7569303512573242 sec per 1 batch
# 6240 img procesed out of 20000, taken 0.902857780456543 sec per 1 batch
# 6560 img procesed out of 20000, taken 0.7610490322113037 sec per 1 batch
# 6880 img procesed out of 20000, taken 0.7602872848510742 sec per 1 batch
# 7200 img procesed out of 20000, taken 0.8939216136932373 sec per 1 batch
# 7520 img procesed out of 20000, taken 0.7590649127960205 sec per 1 batch
